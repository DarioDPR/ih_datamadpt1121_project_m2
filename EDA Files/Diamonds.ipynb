# %%
import pandas as pd

# %% [markdown]
# cut= Fair; Good; Very Good; Premium; Ideal
# color= J-I-H-F-E-D
# clarity= I1-SI1,SI2-VS1,VS2-VVS1,VVS1-IF
# depth= (43.0 - 79.0)
# carat = weight (0.2 - 4.5)
# table =  (43.0 - 95.0)
# x = (0.0 - 10.23)
# y = (0.0 - 58.9)
# z = (0.0 - 8.6)
# price (326 - 18823)
# city = 'Dubai' 'London' 'Surat' 'Paris' 'New York City' 'Kimberly' 'Zurich'
#  'Madrid' 'Antwerp' 'Luxembourg' 'Tel Aviv' 'Las Vegas' 'Amsterdam'

# %%
diamonds = pd.read_csv('./Diamonds.csv')
diamonds
# Out:
#                                                 index_id        cut color  \
# 0      5feceb66ffc86f38d952786c6d696c79c2dbc239dd4e91...    Premium     J
# 1      6b86b273ff34fce19d6b804eff5a3f5747ada4eaa22f1d...  Very Good     H
# 2      d4735e3a265e16eee03f59718b9b5d03019c07d8b6c51f...       Fair     G
# 3      4e07408562bedb8b60ce05c1decfe3ad16b72230967de0...       Good     D
# 4      4b227777d4dd1fc61c6f884f48641d02b4d121d3fd328c...      Ideal     G
# ...                                                  ...        ...   ...
# 40450  f0bc79169405ebeb24e308055156b946ffd819db9b4f75...      Ideal     G
# 40451  339916a23bf22b052b54cb2a9b36ee8418c1c68b46acad...       Good     F
# 40452  46957922b99954654c1deb8d854c3f069bf118b2ce9415...      Ideal     H
# 40453  9d733392d362d5c6f1d9b9659b601c7d4b5a1c1c8df579...      Ideal     J
# 40454  a02744a70faa594d240b067f21fcc23a8d17cd1098a9fb...      Ideal     I
#
#       clarity  depth  carat  table     x     y     z  price       city
# ...

# %%
diamonds.sort_values(by=['price'], inplace=True, ascending = False)
diamonds
# Out:
#                                                 index_id        cut color  \
# 7034   0929b60950cb33cc0a978ad4663611a54497bb4fe44b25...    Premium     I
# 3990   ef501c2555ae9e3de6e23ae39393d64dac510d6d681ba6...  Very Good     G
# 29107  8422ae9c93dc72b3ae57f40eb6a37ecca544506b9cf178...      Ideal     G
# 25529  57be7e56de67f7ae840a06ca4dc42174c38cd24f8461fd...    Premium     I
# 618    ee377871c73631fd6543ddb5164d0b48ea072daa207a91...    Premium     I
# ...                                                  ...        ...   ...
# 12084  5115faeecc0db1adcfda7bb7a3ffd0bbc008309e0e1dba...       Good     J
# 20968  c2bd9d46d24d10ec4ec7d49f295c5555462df32247bb2b...    Premium     I
# 18381  b3884138875a4fff84c082069e1f4adc178c3642c8b872...       Good     E
# 9782   257e3cd0744845b83c0d1f8a114d5c04218844a0c8debe...      Ideal     E
# 18377  a21cefec25404279928e2ffe9d49630f691600cd9d9a1e...    Premium     E
#
#       clarity  depth  carat  table     x     y     z  price           city
# ...

# %%
print(diamonds['city'].unique())
# Out:
# ['Kimberly' 'Madrid' 'New York City' 'Surat' 'Amsterdam' 'Antwerp'
#  'Zurich' 'London' 'Paris' 'Luxembourg' 'Las Vegas' 'Tel Aviv' 'Dubai']

# %%
diamonds['price'].max()
# Out:
# 18823

# %%
diamonds['price'].min()
# Out:
# 326

# %%
diamonds["volume"] = diamonds["x"] * diamonds["y"] * diamonds["z"]
diamonds = diamonds.drop(["x", "y", "z"], axis= 1)
diamonds = diamonds.drop(diamonds.index[diamonds["volume"]== 0], axis= 0)
diamonds
# Out:
#                                                 index_id        cut color  \
# 7034   0929b60950cb33cc0a978ad4663611a54497bb4fe44b25...    Premium     I
# 3990   ef501c2555ae9e3de6e23ae39393d64dac510d6d681ba6...  Very Good     G
# 29107  8422ae9c93dc72b3ae57f40eb6a37ecca544506b9cf178...      Ideal     G
# 25529  57be7e56de67f7ae840a06ca4dc42174c38cd24f8461fd...    Premium     I
# 618    ee377871c73631fd6543ddb5164d0b48ea072daa207a91...    Premium     I
# ...                                                  ...        ...   ...
# 12084  5115faeecc0db1adcfda7bb7a3ffd0bbc008309e0e1dba...       Good     J
# 20968  c2bd9d46d24d10ec4ec7d49f295c5555462df32247bb2b...    Premium     I
# 18381  b3884138875a4fff84c082069e1f4adc178c3642c8b872...       Good     E
# 9782   257e3cd0744845b83c0d1f8a114d5c04218844a0c8debe...      Ideal     E
# 18377  a21cefec25404279928e2ffe9d49630f691600cd9d9a1e...    Premium     E
#
#       clarity  depth  carat  table  price           city      volume
# ...

# %%
diamonds.sort_values(by=['volume'], inplace=True, ascending = False)
diamonds
# Out:
#                                                 index_id        cut color  \
# 14708  daeb96ce8d169c2a9b958853c724d46352d4749b0ebffa...    Premium     H
# 31083  0f1f13ef2ed5183e68c29c8c99f19851b2fc0f226c385d...       Fair     J
# 27893  bd1fcf458ac3909b63648659afad8f05b05a868261ba59...       Fair     H
# 3468   11f4138f4d6ee3c5d5b803a8010f59d227a51fbb2c33f3...    Premium     I
# 2884   8835f492a7c86f65d900be580894bbc8f8becf17daa5c2...  Very Good     I
# ...                                                  ...        ...   ...
# 23007  927fcdcd5c55b3c3cd828fa8e5d5ce7af4e9096d4b9a0b...      Ideal     D
# 6550   e1299b1fe6306876f5135f76e0403dd88c18ef5d0e1352...    Premium     E
# 5157   d937ffa207c3d50aeaeb3cd05f1c5e4fef70246a1b3d21...    Premium     D
# 6423   95d3a6437b56fbcc23f34db6b519c4956c53e2955c76a9...    Premium     E
# 1582   6d78b19a042a64f08cc4df0d42fb91cd757829718e60e8...    Premium     E
#
#       clarity  depth  carat  table  price           city       volume
# ...

# %%
diamonds2 = diamonds.drop(labels = 14708, axis = 0)
diamonds2
# Out:
#                                                 index_id        cut color  \
# 31083  0f1f13ef2ed5183e68c29c8c99f19851b2fc0f226c385d...       Fair     J
# 27893  bd1fcf458ac3909b63648659afad8f05b05a868261ba59...       Fair     H
# 3468   11f4138f4d6ee3c5d5b803a8010f59d227a51fbb2c33f3...    Premium     I
# 2884   8835f492a7c86f65d900be580894bbc8f8becf17daa5c2...  Very Good     I
# 23609  97eae470fe88a1530036f6f95ccb15c9d486a2fc8de1ad...    Premium     J
# ...                                                  ...        ...   ...
# 23007  927fcdcd5c55b3c3cd828fa8e5d5ce7af4e9096d4b9a0b...      Ideal     D
# 6550   e1299b1fe6306876f5135f76e0403dd88c18ef5d0e1352...    Premium     E
# 5157   d937ffa207c3d50aeaeb3cd05f1c5e4fef70246a1b3d21...    Premium     D
# 6423   95d3a6437b56fbcc23f34db6b519c4956c53e2955c76a9...    Premium     E
# 1582   6d78b19a042a64f08cc4df0d42fb91cd757829718e60e8...    Premium     E
#
#       clarity  depth  carat  table  price           city      volume
# ...

# %%
diamonds2.to_csv('diamonds2.csv', index = False)

# %%
diamonds2.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 40438 entries, 31083 to 1582
# Data columns (total 10 columns):
#  #   Column    Non-Null Count  Dtype
# ---  ------    --------------  -----
#  0   index_id  40438 non-null  object
#  1   cut       40438 non-null  object
#  2   color     40438 non-null  object
#  3   clarity   40438 non-null  object
#  4   depth     40438 non-null  float64
#  5   carat     40438 non-null  float64
#  6   table     40438 non-null  float64
#  7   price     40438 non-null  int64
#  8   city      40438 non-null  object
#  9   volume    40438 non-null  float64
# dtypes: float64(4), int64(1), object(5)
# memory usage: 3.4+ MB
